# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello Aakash')
# Out:
# Hello Aakash

# %%
x=10
y='x='+str(x)
print('x=',x)
print(y)
# Out:
# x= 10
# x=10

# %%
x=15
if x<2:
    print(x)
else:
    print ('not successful')
# Out:
# not successful
